# %% [markdown]
# # Tipos de probabilidad.
#
# - Conjunta(joint)
# - Marginal
# - Condicional

# %% [markdown]
# ## Probabilidad conjunta: calcular la probabilidad para varios sucesos conjuntos.
#
# Probabilidad Conjunta.
#
# ![Alt text](img/2023-02-23_22h25_03.png)

# %% [markdown]
# Probabilidad condicional.
#
# ![Alt text](img/2023-02-23_22h36_44.png)

# %% [markdown]
# Probabilidad marginal: La probabilidad marginal es una medida estadística que indica la probabilidad de que ocurra un subconjunto del conjunto total.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image-3.png)
